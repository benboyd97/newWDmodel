# %%
from astropy.io import ascii
from matplotlib import pyplot as plt
#new = ascii.read("vec_new_cal.dat")
new = ascii.read("vec_new_cylces.dat")
old = ascii.read("WDphot_ILAPHv5_abmag.dat")

# %%
bands = ['F275W','F336W','F475W','F625W','F775W','F160W']

# %%
for b in bands:

    fig, (ax_main, ax_sub) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6), gridspec_kw={'height_ratios': [3, 1]})
    ax_main.set_title('WD Magnitude Calibration '+b )
    ax_main.scatter(old[b][4:], new[b][4:], label='Main Plot',color='blue')
    #ax_main.errorbar(old[b][3:], new[b][3:],xerr=old['d'+b][3:], yerr=new['d'+b][3:],fmt='none',color='blue')
    ax_main.set_ylabel('Numpyro (mag)')

    ax_sub.scatter(old[b][4:], new[b][4:]-old[b][4:], label='Smaller Subplot', color='blue')
    #ax_sub.errorbar(old[b][3:], new[b][3:]-old[b][3:],xerr=old['d'+b][3:], yerr=new['d'+b][3:],fmt='none',color='blue')
    ax_sub.set_xlabel('Pymc (mag)')
    ax_sub.set_ylabel('Numpyro - Pymc')

    plt.tight_layout()


    plt.show()

# %%
old
# Out:
# <Table length=30>
#      obj       F275W   dF275W  F336W   dF336W  F475W   dF475W  F625W   dF625W  F775W   dF775W  F160W   dF160W
#     str13     float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64
# ------------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- -------
#     zeropoint  24.057   0.001  24.587   0.001  25.576   0.001  25.405   0.001  24.719   0.001   25.81   0.001
#    c20_offset     nan     nan  -0.033   0.003  -0.009   0.004  -0.014   0.002   0.009   0.004  -0.012   0.005
# sig_intrinsic   0.004   0.001   0.002   0.001   0.003   0.001   0.002   0.001   0.001     0.0   0.005   0.001
#            nu   2.631   0.464   1.695   0.219   2.591   0.447   3.305   0.741   1.443   0.155   3.095   0.552
#       g191b2b  10.488   0.001  10.888   0.001  11.497   0.001   12.03   0.001  12.451   0.001  13.884   0.001
#         gd153  12.199   0.002  12.565   0.002  13.098   0.002  13.597   0.001  14.002   0.001  15.412   0.002
#           ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
#   sdssj041053  18.114   0.009  18.401   0.004  18.878   0.005  19.253   0.003  19.394   0.005  19.497   0.006
#        wd0554  16.773   0.005   17.15   0.004  17.725   0.005   18.22   0.003  18.617   0.005  20.042   0.007
#   sdssj120650  18.237   0.004  18.486   0.004   18.67   0.004  19.059   0.003  19.411   0.006  20.701   0.009
#   sdssj131445  18.255   0.004  18.594   0.005    19.1   0.005  19.566   0.005  19.955   0.009  21.327   0.012
#   sdssj163800  18.013   0.008  18.315   0.004  18.838   0.005   19.28   0.003   19.66   0.005  20.995   0.009
#   sdssj203722  18.254   0.007  18.541   0.004  18.941   0.006  19.349   0.012  19.672    0.01  20.977   0.023
#   sdssj232941  17.941   0.004  18.106   0.004  18.159   0.006  18.469   0.003  18.775   0.007  19.993   0.007

# %%
new
# Out:
# <Table length=30>
#     obj_ID      F275W    dF275W    F336W    dF336W    F475W    dF475W    F625W    dF625W    F775W    dF775W    F160W    dF160W
#     str13      float64  float64   float64  float64   float64  float64   float64  float64   float64  float64   float64  float64
# ------------- --------- -------- --------- -------- --------- -------- --------- -------- --------- -------- --------- --------
#     zeropoint 24.057054 0.000801  24.58712  0.00085 25.575864 0.000807 25.404559 0.000615  24.71888  0.00059 25.809948 0.000832
#    c20_offset       nan      nan -0.032474 0.002749  -0.00925 0.003608 -0.013844 0.002207  0.008739 0.004119 -0.012407 0.005343
# sig_intrinsic  0.003637 0.003637  0.002369 0.002369  0.003018 0.003018  0.001786 0.001786   0.00054  0.00054  0.004746 0.004746
#            nu  2.618684 0.458656  1.696109 0.219591  2.594112 0.436204   3.29815 0.746756  1.445789 0.155175  3.097318  0.53759
#       g191b2b 10.487763 0.001467 10.887515 0.001406 11.497353 0.001298 12.029662  0.00103 12.451342 0.001223 13.883588 0.001474
#         gd153 12.199075 0.001587 12.565176  0.00151 13.098283 0.001766 13.596667 0.001385 14.001771 0.001236 15.412263  0.00169
#           ...       ...      ...       ...      ...       ...      ...       ...      ...       ...      ...       ...      ...
#   sdssj041053 18.113745 0.009154 18.401443 0.004038  18.87798 0.004768 19.252704 0.003258 19.393464 0.005395 19.496698 0.005597
#        wd0554 16.773199 0.004863 17.150281 0.003683 17.725161 0.004853 18.219511 0.002598 18.617105 0.004979 20.041553 0.007033
#   sdssj120650 18.237177 0.004107 18.486071  0.00415 18.670378 0.004453 19.059161 0.002994 19.411247 0.006482 20.701008 0.008429
#   sdssj131445 18.255296 0.004502 18.594159 0.005058 19.100247 0.004757 19.565806 0.004524 19.955402 0.008541 21.326606 0.012338
#   sdssj163800 18.013225 0.006917 18.314986 0.004092 18.837986 0.004753 19.279908  0.00329 19.660399 0.004757 20.994645 0.008781
#   sdssj203722 18.253586 0.008106 18.541197 0.004453 18.941036 0.005959 19.349604 0.011187 19.671775 0.009778 20.976825 0.023441
#   sdssj232941 17.940994 0.003751 18.106326  0.00384 18.158746 0.005563  18.46864 0.002729 18.775525 0.007065 19.993344 0.006815

# %%
old[1]
# Out:
# <Row index=1>
#    obj      F275W   dF275W  F336W   dF336W  F475W   dF475W  F625W   dF625W  F775W   dF775W  F160W   dF160W
#   str13    float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64
# ---------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- -------
# c20_offset     nan     nan  -0.033   0.003  -0.009   0.004  -0.014   0.002   0.009   0.004  -0.012   0.005

# %%
new[1]
# Out:
# <Row index=1>
#   obj_ID    F275W   dF275W   F336W    dF336W   F475W    dF475W    F625W    dF625W   F775W    dF775W    F160W    dF160W
#   str13    float64 float64  float64  float64  float64  float64   float64  float64  float64  float64   float64  float64
# ---------- ------- ------- --------- -------- -------- -------- --------- -------- -------- -------- --------- --------
# c20_offset     nan     nan -0.032474 0.002749 -0.00925 0.003608 -0.013844 0.002207 0.008739 0.004119 -0.012407 0.005343

# %%
import numpy as np

for b in bands:
    print(new[b][0]-old[b][0])
# Out:
# 5.400000000221894e-05
# 0.00011999999999900979
# -0.00013600000000124624
# -0.00044100000000213413
# -0.0001200000000025625
# -5.200000000016303e-05

# %%
import numpy as np

for b in bands:
    print(new[b][1]-old[b][1])
# Out:
# nan
# 0.0005259999999999987
# -0.0002500000000000002
# 0.0001559999999999999
# -0.0002609999999999991
# -0.0004069999999999994
